# %% [markdown]
# ###Write function RemoveExclamationMarks which removes all exclamation marks from a given string.

# %%
def remove_exclamation_marks(string):
    a=""
    for i in string:
        if i !="!":
            a+=i
    string=a
    return a
remove_exclamation_marks("Hi! Im here !")
