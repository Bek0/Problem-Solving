# %% [markdown]
# You will be given an array that contains two strings. Your job is to create a function that will take those two strings and transpose them, so that the strings go from top to bottom instead of left to right.
#
# e.g. transposeTwoStrings(['Hello','World']);
#
# should return
#
# H W
# e o
# l r
# l l
# o d
#
# A few things to note:
#
# There should be one space in between the two characters
# You don't have to modify the case (i.e. no need to change to upper or lower)
#
# If one string is longer than the other, there should be a space where the character would be

# %%
def transpose_two_strings(arr):
      y=2
      all=""
      list1=[]
      for p in arr:
        list1.append(len(str(p)))

      r=list1.index(max(list1))
      i=0
      while((i<=max(list1)-1)):
        for k in range(0,1):
          if (i<=min(list1)-1):
            if(i<max(list1)-1):
              all+=arr[0][i]+" "+arr[1][i]+"\n"
            else:
              all+=arr[0][i]+" "+arr[1][i]
          else:
            if(i<max(list1)-1):
              if r == 1:
                all+=" "+" "+arr[1][i]+"\n"
              else:
                all+=arr[0][i]+" "+" "+"\n"
              if min(list1)==0:
                break
            else:
              if r == 1:
                all+=" "+" "+arr[1][i]
              else:
                all+=arr[0][i]+" "+" "
              if min(list1)==0:
                break
        i+=1
      return all

print(transpose_two_strings(["MyNameIsBakr","Im18YearsOld"]))
print("_______________________________________")
print(transpose_two_strings(["MyNameIsHamza","Im18YearsOld"]))
print("_______________________________________")
print(transpose_two_strings(["MyNameIsAli","Im18YearsOld"]))
